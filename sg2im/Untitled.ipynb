# %%
import pickle as p 
import os
import cv2

path = "/mnt/lustre/liuruiyang/code/varscene/sg2im/outputs/"

# %%
file_list = {}
for file in os.listdir(path):
    f = open(os.path.join(path, file), 'rb')
    f = p.load(f)
    print(f)
    cv2.imshow('img', f)
# Out:
# [[[[ 56  46  40 ...  74  71  81]
#    [ 54  43  43 ...  77  78  75]
#    [ 48  45  44 ...  81  83  84]
#    ...
#    [119 122 120 ... 136 131 124]
#    [112 115 119 ... 129 124 120]
#    [101 102 117 ... 124 125 125]]
#
#   [[ 50  52  46 ...  78  76  88]
#    [ 52  47  43 ...  82  82  80]
#    [ 50  48  45 ...  86  86  87]
#    ...
#    [128 129 130 ... 131 126 123]
#    [123 123 127 ... 125 119 115]
#    [110 111 124 ... 122 119 116]]
#
#   [[ 36  34  31 ...  64  59  72]
#    [ 40  36  33 ...  66  65  69]
#    [ 38  34  31 ...  70  70  73]
#    ...
#    [ 67  70  67 ...  94  89  87]
#    [ 68  72  69 ...  90  86  89]
#    [ 69  63  69 ...  83  80  89]]]
#
#
#  [[[121 114 104 ... 110 105 110]
#    [110 101 100 ... 106 106 107]
#    [106 103 103 ... 108 106 108]
#    ...
#    [188 193 193 ... 172 168 150]
#    [189 195 195 ... 169 164 147]
#    [180 192 194 ... 158 154 143]]
#
#   [[112 118 113 ... 111 108 113]
#    [112 108 108 ... 107 107 111]
#    [109 110 112 ... 110 108 110]
# ...

# %%
# img = file_list
# cv2.imshow('img', f)
